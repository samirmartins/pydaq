# %% [markdown]
# ---
# # NOTE 1: file [arduino_code.ino](https://github.com/samirmartins/pydaq/blob/359823ffb244d6a3ee8124c57c3c2002281df8d8/pydaq/arduino_code/arduino_code.ino) should be loaded in Arduino before running this example
#
# # Note 2: only digital outputs allowed in Arduino
# ---
# # Example #2
# ---
# ### How to use Send_data (and send_data_arduino_gui) Graphical User Interface to send a signal from a file using an Arduino board
# ---

# %% [markdown]
# ### Importing library and starting up the GUI (Graphical User Interface)

# %%
from pydaq.pydaq_global import PydaqGui

# Launch the interface
gui = PydaqGui()
# Out:
# Iteration: 0 of 20
# Iteration: 1 of 20
# Iteration: 2 of 20
# Iteration: 3 of 20
# Iteration: 4 of 20
# Iteration: 5 of 20
# Iteration: 6 of 20
# Iteration: 7 of 20
# Iteration: 8 of 20
# Iteration: 9 of 20
# Iteration: 10 of 20
# Iteration: 11 of 20
# Iteration: 12 of 20
# Iteration: 13 of 20
# Iteration: 14 of 20
# Iteration: 15 of 20
# Iteration: 16 of 20
# Iteration: 17 of 20
# Iteration: 18 of 20
# Iteration: 19 of 20
# Iteration: 20 of 20
