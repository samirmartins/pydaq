# %% [markdown]
# ---
# # Quick example
# ---
# ### How to use get_data_nidaqmx_gui (Graphical User Interface) to acquire signal using an National Instruments board
# ---

# %% [markdown]
# ### Importing library and starting up the GUI (Graphical User Interface)

# %%
from pydaq.get_data_nidaqmx_gui import get_data_nidaqmx_gui

get_data_nidaqmx_gui()
