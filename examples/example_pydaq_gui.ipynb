# %% [markdown]
# ---
# # NOTE: file [arduino_code.ino](https://github.com/samirmartins/pydaq/blob/359823ffb244d6a3ee8124c57c3c2002281df8d8/pydaq/arduino_code/arduino_code.ino) should be loaded in Arduino before running this example
# ---
# # Example
# ---
# ### How to use the graphical user interface to use all PYDAQ's functionalities
# ---
# # The instruction for each functionality in the GUI, can be found [here](https://samirmartins.github.io/pydaq/)
# ---

# %% [markdown]
# ### Importing library and starting up the GUI (Graphical User Interface)

# %%
from pydaq.pydaq_global import PydaqGui

# Launch the interface
gui = PydaqGui()  # You can use this object to access the data
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\pydaq\guis\getdata_arduino_widget.py:84, in GetData_Arduino_Widget.start_func_get_data(self)
#      80     g.error_path = True
#      82 if not g.error_path:
#      83     # Calling data aquisition method
# ---> 84     g.get_data_arduino()
#      85     self.signals.returned.emit(g)
#
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\pydaq\get_data.py:207, in GetData.get_data_arduino(self)
#     204 self.ser.reset_input_buffer()  # Reseting serial input buffer
#     205 # print(self.ser.read(14).split())
#     206 # Get the last complete value
# --> 207 temp = int(self.ser.read(14).split()[-2].decode("UTF-8")) * self.ard_vpb
#     208 # temp = 5
#     209 # Queue data in a list
#     210 self.data.append(temp)
#
# IndexError: list index out of range
# Iteration: 0 of 20
# Iteration: 1 of 20
# Iteration: 2 of 20
# Iteration: 3 of 20
# Iteration: 4 of 20
# Iteration: 5 of 20
# Iteration: 6 of 20
# Iteration: 7 of 20
# Iteration: 8 of 20
# Iteration: 9 of 20
# Iteration: 10 of 20
# Iteration: 11 of 20
# Iteration: 12 of 20
# Iteration: 13 of 20
# Iteration: 14 of 20
# Iteration: 15 of 20
# Iteration: 16 of 20
# Iteration: 17 of 20
# Iteration: 18 of 20
# Iteration: 19 of 20
# Iteration: 20 of 20
#
# Saving data ...
#
# Data saved ...
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\pydaq\guis\senddata_arduino_widget.py:85, in SendData_Arduino_Widget.start_func_send_data(self)
#      81     s.error_path = True
#      83 if not s.error_path:
#      84     # Calling send data method
# ---> 85     s.send_data_arduino()
#      86     self.signals.returned.emit(s)
#
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\pydaq\send_data.py:176, in SendData.send_data_arduino(self)
#     173 self.cycles = len(self.data)
#     175 # Opening ports and serial communication
# --> 176 self._open_serial()
#     178 # Rearranjing data to be send and also loaded data
#     179 self.data_send = list(self.data).copy()
#
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\pydaq\utils\base.py:58, in Base._open_serial(self)
#      55 self.ser.port = self.com_port  # Defining port
#      57 if not self.ser.isOpen():  # Open port if not openned
# ---> 58     self.ser.open()
#
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\venv\lib\site-packages\serial\serialwin32.py:64, in Serial.open(self)
#      62 if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      63     self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64     raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      66 try:
#      67     self._overlapped_read = win32.OVERLAPPED()
#
# SerialException: could not open port 'COM6': PermissionError(13, 'Acesso negado.', None, 5)
# 21
# Iteration: 0 of 20
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\pydaq\guis\senddata_arduino_widget.py:85, in SendData_Arduino_Widget.start_func_send_data(self)
#      81     s.error_path = True
#      83 if not s.error_path:
#      84     # Calling send data method
# ---> 85     s.send_data_arduino()
#      86     self.signals.returned.emit(s)
#
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\pydaq\send_data.py:176, in SendData.send_data_arduino(self)
#     173 self.cycles = len(self.data)
#     175 # Opening ports and serial communication
# --> 176 self._open_serial()
#     178 # Rearranjing data to be send and also loaded data
#     179 self.data_send = list(self.data).copy()
#
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\pydaq\utils\base.py:58, in Base._open_serial(self)
#      55 self.ser.port = self.com_port  # Defining port
#      57 if not self.ser.isOpen():  # Open port if not openned
# ---> 58     self.ser.open()
#
# File D:\Outros Codigos\Pydaq_Pyside6\pydaq\venv\lib\site-packages\serial\serialwin32.py:64, in Serial.open(self)
#      62 if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      63     self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64     raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      66 try:
#      67     self._overlapped_read = win32.OVERLAPPED()
#
# SerialException: could not open port 'COM6': PermissionError(13, 'Acesso negado.', None, 5)
# Iteration: 1 of 20
# Iteration: 2 of 20
# Iteration: 3 of 20
# Iteration: 4 of 20
# Iteration: 5 of 20
# Iteration: 6 of 20
# Iteration: 7 of 20
# Iteration: 8 of 20
# Iteration: 9 of 20
# Iteration: 10 of 20
# Iteration: 11 of 20
# Iteration: 12 of 20
# Iteration: 13 of 20
# Iteration: 14 of 20
# Iteration: 15 of 20
# Iteration: 16 of 20
# Iteration: 17 of 20
# Iteration: 18 of 20
# Iteration: 19 of 20
# Iteration: 20 of 20
